# %%
# %load_ext autoreload
# %autoreload 2
from operators import FermionSystemSpec
import cupy as cp
import numpy as np
from matrixensembles import XXZ
from operators import FermionSystemSpec
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
xxz = XXZ(0, 0.2, 0.5, FermionSystemSpec(18, 3))
xxz.collect()
e = xxz.eigenvalues()
fig, ax = plt.subplots()
_ = ax.hist(xxz.s().flatten(), bins=100, range=(0, 3))
